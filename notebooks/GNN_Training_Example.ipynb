# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/AlexMorman/ncrna_generation.git
# %cd ncrna_generation
# Out:
# Cloning into 'ncrna_generation'...
# remote: Enumerating objects: 3412, done.
# remote: Counting objects: 100% (3412/3412), done.
# remote: Compressing objects: 100% (3373/3373), done.
# remote: Total 3412 (delta 51), reused 3384 (delta 33), pack-reused 0 (from 0)
# Receiving objects: 100% (3412/3412), 2.26 MiB | 6.66 MiB/s, done.
# Resolving deltas: 100% (51/51), done.
# /content/ncrna_generation

# %%
# PyTorch Geometric
# !pip install torch-geometric --quiet

# Config and plotting
# !pip install pyyaml matplotlib --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.0 MB/s eta 0:00:00

# %%
# !ls data/raw/RF04331/ | head -5
# !ls data/raw/RF04331/*.sto
# Out:
# RF04331.sto
# Sequence_1000.ss.ct
# Sequence_1001.ss.ct
# Sequence_1002.ss.ct
# Sequence_1003.ss.ct
# data/raw/RF04331/RF04331.sto

# %%
# !sed -i 's/target_family:.*/target_family: RF04331/' configs/config.yaml

# !python train.py --config configs/config.yaml
# Out:
# Device: cuda
# Processing...
# Failed 'Sequence_1.ss.ct': CT file 'data/raw/RF04331/Sequence_1.ss.ct': pseudoknot detected — pairs (14,35) and (18,45) cross.
# Failed 'Sequence_10.ss.ct': CT file 'data/raw/RF04331/Sequence_10.ss.ct': pseudoknot detected — pairs (1,20) and (7,33) cross.
# Failed 'Sequence_100.ss.ct': CT file 'data/raw/RF04331/Sequence_100.ss.ct': pseudoknot detected — pairs (8,36) and (9,37) cross.
# Failed 'Sequence_1000.ss.ct': CT file 'data/raw/RF04331/Sequence_1000.ss.ct': pseudoknot detected — pairs (14,38) and (23,41) cross.
# Failed 'Sequence_1001.ss.ct': CT file 'data/raw/RF04331/Sequence_1001.ss.ct': pseudoknot detected — pairs (7,40) and (21,43) cross.
# Failed 'Sequence_1004.ss.ct': CT file 'data/raw/RF04331/Sequence_1004.ss.ct': pseudoknot detected — pairs (13,23) and (14,28) cross.
# Failed 'Sequence_1008.ss.ct': CT file 'data/raw/RF04331/Sequence_1008.ss.ct': pseudoknot detected — pairs (15,29) and (16,30) cross.
# Failed 'Sequence_1009.ss.ct': CT file 'data/raw/RF04331/Sequence_1009.ss.ct': pseudoknot detected — pairs (8,38) and (9,41) cross.
# Failed 'Sequence_101.ss.ct': CT file 'data/raw/RF04331/Sequence_101.ss.ct': pseudoknot detected — pairs (1,40) and (2,41) cross.
# Failed 'Sequence_1010.ss.ct': CT file 'data/raw/RF04331/Sequence_1010.ss.ct': pseudoknot detected — pairs (5,37) and (6,38) cross.
# Failed 'Sequence_1011.ss.ct': CT file 'data/raw/RF04331/Sequence_1011.ss.ct': pseudoknot detected — pairs (9,34) and (11,36) cross.
# Failed 'Sequence_1013.ss.ct': CT file 'data/raw/RF04331/Sequence_1013.ss.ct': pseudoknot detected — pairs (2,14) and (11,22) cross.
# Failed 'Sequence_1014.ss.ct': CT file 'data/raw/RF04331/Sequence_1014.ss.ct': pseudoknot detected — pairs (9,32) and (11,33) cross.
# Failed 'Sequence_1015.ss.ct': CT file 'data/raw/RF04331/Sequence_1015.ss.ct': pseudoknot detected — pairs (4,34) and (6,36) cross.
# Failed 'Sequence_1019.ss.ct': CT file 'data/raw/RF04331/Sequence_1019.ss.ct': pseudoknot detected — pairs (6,34) and (7,35) cross.
# Failed 'Sequence_1023.ss.ct': CT file 'data/raw/RF04331/Sequence_1023.ss.ct': pseudoknot detected — pairs (1,30) and (2,31) cross.
# Failed 'Sequence_1024.ss.ct': CT file 'data/raw/RF04331/Sequence_1024.ss.ct': pseudoknot detected — pairs (1,17) and (4,41) cross.
# Failed 'Sequence_1025.ss.ct': CT file 'data/raw/RF04331/Sequence_1025.ss.ct': pseudoknot detected — pairs (5,38) and (7,39) cross.
# Failed 'Sequence_1027.ss.ct': CT file 'data/raw/RF04331/Sequence_1027.ss.ct': pseudoknot detected — pairs (15,21) and (16,22) cross.
# Failed 'Sequence_1028.ss.ct': CT file 'data/raw/RF04331/Sequence_1028.ss.ct': pseudoknot detected — pairs (30,44) and (37,45) cross.
# Failed 'Sequence_1029.ss.ct': CT file 'data/raw/RF04331/Sequence_1029.ss.ct': pseudoknot detected — pairs (3,32) and (6,34) cross.
# Failed 'Sequence_1030.ss.ct': CT file 'data/raw/RF04331/Sequence_1030.ss.ct': pseudoknot detected — pairs (1,46) and (4,47) cross.
# Failed 'Sequence_1033.ss.ct': CT file 'data/raw/RF04331/Sequence_1033.ss.ct': pseudoknot detected — pairs (4,16) and (9,29) cross.
# Failed 'Sequence_1036.ss.ct': CT file 'data/raw/RF04331/Sequence_1036.ss.ct': pseudoknot detected — pairs (2,15) and (5,16) cross.
# Failed 'Sequence_1037.ss.ct': CT file 'data/raw/RF04331/Sequence_1037.ss.ct': pseudoknot detected — pairs (3,12) and (4,42) cross.
# Failed 'Sequence_1039.ss.ct': CT file 'data/raw/RF04331/Sequence_1039.ss.ct': pseudoknot detected — pairs (3,20) and (5,21) cross.
# Failed 'Sequence_104.ss.ct': CT file 'data/raw/RF04331/Sequence_104.ss.ct': pseudoknot detected — pairs (2,10) and (6,31) cross.
# Failed 'Sequence_1041.ss.ct': CT file 'data/raw/RF04331/Sequence_1041.ss.ct': pseudoknot detected — pairs (1,35) and (12,45) cross.
# Failed 'Sequence_1043.ss.ct': CT file 'data/raw/RF04331/Sequence_1043.ss.ct': pseudoknot detected — pairs (12,32) and (17,49) cross.
# Failed 'Sequence_1045.ss.ct': CT file 'data/raw/RF04331/Sequence_1045.ss.ct': pseudoknot detected — pairs (16,35) and (20,40) cross.
# Failed 'Sequence_1047.ss.ct': CT file 'data/raw/RF04331/Sequence_1047.ss.ct': pseudoknot detected — pairs (3,44) and (4,45) cross.
# Failed 'Sequence_1049.ss.ct': CT file 'data/raw/RF04331/Sequence_1049.ss.ct': pseudoknot detected — pairs (5,17) and (7,20) cross.
# Failed 'Sequence_105.ss.ct': CT file 'data/raw/RF04331/Sequence_105.ss.ct': pseudoknot detected — pairs (4,13) and (7,25) cross.
# Failed 'Sequence_1053.ss.ct': CT file 'data/raw/RF04331/Sequence_1053.ss.ct': pseudoknot detected — pairs (17,23) and (18,24) cross.
# Failed 'Sequence_1056.ss.ct': CT file 'data/raw/RF04331/Sequence_1056.ss.ct': pseudoknot detected — pairs (8,31) and (9,35) cross.
# Failed 'Sequence_1057.ss.ct': CT file 'data/raw/RF04331/Sequence_1057.ss.ct': pseudoknot detected — pairs (9,31) and (11,33) cross.
# Failed 'Sequence_1058.ss.ct': CT file 'data/raw/RF04331/Sequence_1058.ss.ct': pseudoknot detected — pairs (4,34) and (7,35) cross.
# Failed 'Sequence_106.ss.ct': CT file 'data/raw/RF04331/Sequence_106.ss.ct': pseudoknot detected — pairs (4,23) and (6,33) cross.
# Failed 'Sequence_1060.ss.ct': CT file 'data/raw/RF04331/Sequence_1060.ss.ct': pseudoknot detected — pairs (1,27) and (2,29) cross.
# Failed 'Sequence_1061.ss.ct': CT file 'data/raw/RF04331/Sequence_1061.ss.ct': pseudoknot detected — pairs (3,46) and (8,47) cross.
# Failed 'Sequence_1064.ss.ct': CT file 'data/raw/RF04331/Sequence_1064.ss.ct': pseudoknot detected — pairs (3,14) and (5,35) cross.
# Failed 'Sequence_1066.ss.ct': CT file 'data/raw/RF04331/Sequence_1066.ss.ct': pseudoknot detected — pairs (11,33) and (13,34) cross.
# Failed 'Sequence_1080.ss.ct': CT file 'data/raw/RF04331/Sequence_1080.ss.ct': pseudoknot detected — pairs (5,18) and (9,19) cross.
# Failed 'Sequence_1087.ss.ct': CT file 'data/raw/RF04331/Sequence_1087.ss.ct': pseudoknot detected — pairs (1,19) and (8,32) cross.
# Failed 'Sequence_1088.ss.ct': CT file 'data/raw/RF04331/Sequence_1088.ss.ct': pseudoknot detected — pairs (10,37) and (12,38) cross.
# Failed 'Sequence_1089.ss.ct': CT file 'data/raw/RF04331/Sequence_1089.ss.ct': pseudoknot detected — pairs (6,15) and (8,29) cross.
# Failed 'Sequence_109.ss.ct': CT file 'data/raw/RF04331/Sequence_109.ss.ct': pseudoknot detected — pairs (1,25) and (9,32) cross.
# Failed 'Sequence_1090.ss.ct': CT file 'data/raw/RF04331/Sequence_1090.ss.ct': pseudoknot detected — pairs (2,17) and (5,19) cross.
# Failed 'Sequence_1091.ss.ct': CT file 'data/raw/RF04331/Sequence_1091.ss.ct': pseudoknot detected — pairs (2,27) and (4,47) cross.
# Failed 'Sequence_1092.ss.ct': CT file 'data/raw/RF04331/Sequence_1092.ss.ct': pseudoknot detected — pairs (12,37) and (13,38) cross.
# Failed 'Sequence_1093.ss.ct': CT file 'data/raw/RF04331/Sequence_1093.ss.ct': pseudoknot detected — pairs (11,16) and (15,30) cross.
# Failed 'Sequence_1094.ss.ct': CT file 'data/raw/RF04331/Sequence_1094.ss.ct': pseudoknot detected — pairs (10,16) and (12,24) cross.
# Failed 'Sequence_1095.ss.ct': CT file 'data/raw/RF04331/Sequence_1095.ss.ct': pseudoknot detected — pairs (1,18) and (9,26) cross.
# Failed 'Sequence_1096.ss.ct': CT file 'data/raw/RF04331/Sequence_1096.ss.ct': pseudoknot detected — pairs (2,11) and (4,35) cross.
# Failed 'Sequence_1097.ss.ct': CT file 'data/raw/RF04331/Sequence_1097.ss.ct': pseudoknot detected — pairs (2,32) and (13,38) cross.
# Failed 'Sequence_1099.ss.ct': CT file 'data/raw/RF04331/Sequence_1099.ss.ct': pseudoknot detected — pairs (22,34) and (23,35) cross.
# Failed 'Sequence_11.ss.ct': CT file 'data/raw/RF04331/Sequence_11.ss.ct': pseudoknot detected — pairs (3,18) and (6,19) cross.
# Failed 'Sequence_110.ss.ct': CT file 'data/raw/RF04331/Sequence_110.ss.ct': pseudoknot detected — pairs (11,14) and (12,17) cross.
# Failed 'Sequence_1100.ss.ct': CT file 'data/raw/RF04331/Sequence_1100.ss.ct': pseudoknot detected — pairs (30,38) and (32,45) cross.
# Failed 'Sequence_1102.ss.ct': CT file 'data/raw/RF04331/Sequence_1102.ss.ct': pseudoknot detected — pairs (3,18) and (6,20) cross.
# Failed 'Sequence_1103.ss.ct': CT file 'data/raw/RF04331/Sequence_1103.ss.ct': pseudoknot detected — pairs (2,17) and (10,43) cross.
# Failed 'Sequence_1107.ss.ct': CT file 'data/raw/RF04331/Sequence_1107.ss.ct': pseudoknot detected — pairs (1,18) and (8,34) cross.
# Failed 'Sequence_111.ss.ct': CT file 'data/raw/RF04331/Sequence_111.ss.ct': pseudoknot detected — pairs (15,18) and (17,20) cross.
# Failed 'Sequence_1111.ss.ct': CT file 'data/raw/RF04331/Sequence_1111.ss.ct': pseudoknot detected — pairs (2,9) and (3,46) cross.
# Failed 'Sequence_1112.ss.ct': CT file 'data/raw/RF04331/Sequence_1112.ss.ct': pseudoknot detected — pairs (5,38) and (30,42) cross.
# Failed 'Sequence_1113.ss.ct': CT file 'data/raw/RF04331/Sequence_1113.ss.ct': pseudoknot detected — pairs (10,35) and (14,37) cross.
# Failed 'Sequence_1115.ss.ct': CT file 'data/raw/RF04331/Sequence_1115.ss.ct': pseudoknot detected — pairs (9,44) and (11,45) cross.
# Failed 'Sequence_1125.ss.ct': CT file 'data/raw/RF04331/Sequence_1125.ss.ct': pseudoknot detected — pairs (2,41) and (10,42) cross.
# Failed 'Sequence_1129.ss.ct': CT file 'data/raw/RF04331/Sequence_1129.ss.ct': pseudoknot detected — pairs (7,36) and (10,38) cross.
# Failed 'Sequence_113.ss.ct': CT file 'data/raw/RF04331/Sequence_113.ss.ct': pseudoknot detected — pairs (1,21) and (13,26) cross.
# Failed 'Sequence_1131.ss.ct': CT file 'data/raw/RF04331/Sequence_1131.ss.ct': pseudoknot detected — pairs (6,26) and (7,27) cross.
# Failed 'Sequence_1133.ss.ct': CT file 'data/raw/RF04331/Sequence_1133.ss.ct': pseudoknot detected — pairs (2,11) and (5,42) cross.
# Failed 'Sequence_1137.ss.ct': CT file 'data/raw/RF04331/Sequence_1137.ss.ct': pseudoknot detected — pairs (3,28) and (4,31) cross.
# Failed 'Sequence_1139.ss.ct': CT file 'data/raw/RF04331/Sequence_1139.ss.ct': pseudoknot detected — pairs (1,40) and (3,42) cross.
# Failed 'Sequence_1140.ss.ct': CT file 'data/raw/RF04331/Sequence_1140.ss.ct': pseudoknot detected — pairs (3,20) and (5,21) cross.
# Failed 'Sequence_1142.ss.ct': CT file 'data/raw/RF04331/Sequence_1142.ss.ct': pseudoknot detected — pairs (8,40) and (9,41) cross.
# Failed 'Sequence_1144.ss.ct': CT file 'data/raw/RF04331/Sequence_1144.ss.ct': pseudoknot detected — pairs (1,17) and (12,32) cross.
# Failed 'Sequence_1146.ss.ct': CT file 'data/raw/RF04331/Sequence_1146.ss.ct': pseudoknot detected — pairs (6,26) and (7,27) cross.
# Failed 'Sequence_1147.ss.ct': CT file 'data/raw/RF04331/Sequence_1147.ss.ct': pseudoknot detected — pairs (8,32) and (12,33) cross.
# Failed 'Sequence_1149.ss.ct': CT file 'data/raw/RF04331/Sequence_1149.ss.ct': pseudoknot detected — pairs (9,42) and (12,43) cross.
# Failed 'Sequence_1150.ss.ct': CT file 'data/raw/RF04331/Sequence_1150.ss.ct': pseudoknot detected — pairs (6,32) and (7,38) cross.
# Failed 'Sequence_1152.ss.ct': CT file 'data/raw/RF04331/Sequence_1152.ss.ct': pseudoknot detected — pairs (8,24) and (11,26) cross.
# Failed 'Sequence_1156.ss.ct': CT file 'data/raw/RF04331/Sequence_1156.ss.ct': pseudoknot detected — pairs (1,37) and (2,38) cross.
# Failed 'Sequence_1157.ss.ct': CT file 'data/raw/RF04331/Sequence_1157.ss.ct': pseudoknot detected — pairs (5,29) and (6,30) cross.
# Failed 'Sequence_116.ss.ct': CT file 'data/raw/RF04331/Sequence_116.ss.ct': pseudoknot detected — pairs (8,30) and (9,34) cross.
# Failed 'Sequence_1161.ss.ct': CT file 'data/raw/RF04331/Sequence_1161.ss.ct': pseudoknot detected — pairs (1,29) and (6,47) cross.
# Failed 'Sequence_1162.ss.ct': CT file 'data/raw/RF04331/Sequence_1162.ss.ct': pseudoknot detected — pairs (6,37) and (7,41) cross.
# Failed 'Sequence_1163.ss.ct': CT file 'data/raw/RF04331/Sequence_1163.ss.ct': pseudoknot detected — pairs (1,24) and (2,25) cross.
# Failed 'Sequence_1166.ss.ct': CT file 'data/raw/RF04331/Sequence_1166.ss.ct': pseudoknot detected — pairs (6,31) and (7,32) cross.
# Failed 'Sequence_1167.ss.ct': CT file 'data/raw/RF04331/Sequence_1167.ss.ct': pseudoknot detected — pairs (5,40) and (7,42) cross.
# Failed 'Sequence_1169.ss.ct': CT file 'data/raw/RF04331/Sequence_1169.ss.ct': pseudoknot detected — pairs (4,19) and (5,21) cross.
# Failed 'Sequence_1171.ss.ct': CT file 'data/raw/RF04331/Sequence_1171.ss.ct': pseudoknot detected — pairs (3,42) and (5,44) cross.
# Failed 'Sequence_1172.ss.ct': CT file 'data/raw/RF04331/Sequence_1172.ss.ct': pseudoknot detected — pairs (1,10) and (7,17) cross.
# Failed 'Sequence_1173.ss.ct': CT file 'data/raw/RF04331/Sequence_1173.ss.ct': pseudoknot detected — pairs (36,45) and (37,49) cross.
# Failed 'Sequence_1174.ss.ct': CT file 'data/raw/RF04331/Sequence_1174.ss.ct': pseudoknot detected — pairs (5,24) and (6,25) cross.
# Failed 'Sequence_1175.ss.ct': CT file 'data/raw/RF04331/Sequence_1175.ss.ct': pseudoknot detected — pairs (11,27) and (12,32) cross.
# Failed 'Sequence_1177.ss.ct': CT file 'data/raw/RF04331/Sequence_1177.ss.ct': pseudoknot detected — pairs (1,47) and (3,49) cross.
# Failed 'Sequence_1179.ss.ct': CT file 'data/raw/RF04331/Sequence_1179.ss.ct': pseudoknot detected — pairs (7,34) and (8,38) cross.
# Failed 'Sequence_118.ss.ct': CT file 'data/raw/RF04331/Sequence_118.ss.ct': pseudoknot detected — pairs (10,15) and (11,16) cross.
# Failed 'Sequence_1181.ss.ct': CT file 'data/raw/RF04331/Sequence_1181.ss.ct': pseudoknot detected — pairs (2,24) and (12,25) cross.
# Failed 'Sequence_1183.ss.ct': CT file 'data/raw/RF04331/Sequence_1183.ss.ct': pseudoknot detected — pairs (17,33) and (24,38) cross.
# Failed 'Sequence_1187.ss.ct': CT file 'data/raw/RF04331/Sequence_1187.ss.ct': pseudoknot detected — pairs (2,20) and (4,21) cross.
# Failed 'Sequence_1189.ss.ct': CT file 'data/raw/RF04331/Sequence_1189.ss.ct': pseudoknot detected — pairs (13,27) and (14,36) cross.
# Failed 'Sequence_1190.ss.ct': CT file 'data/raw/RF04331/Sequence_1190.ss.ct': pseudoknot detected — pairs (11,27) and (12,30) cross.
# Failed 'Sequence_1191.ss.ct': CT file 'data/raw/RF04331/Sequence_1191.ss.ct': pseudoknot detected — pairs (2,21) and (10,42) cross.
# Failed 'Sequence_1196.ss.ct': CT file 'data/raw/RF04331/Sequence_1196.ss.ct': pseudoknot detected — pairs (2,25) and (10,31) cross.
# Failed 'Sequence_1198.ss.ct': CT file 'data/raw/RF04331/Sequence_1198.ss.ct': pseudoknot detected — pairs (1,26) and (4,36) cross.
# Failed 'Sequence_1199.ss.ct': CT file 'data/raw/RF04331/Sequence_1199.ss.ct': pseudoknot detected — pairs (2,24) and (8,36) cross.
# Failed 'Sequence_12.ss.ct': CT file 'data/raw/RF04331/Sequence_12.ss.ct': pseudoknot detected — pairs (8,27) and (9,28) cross.
# Failed 'Sequence_120.ss.ct': CT file 'data/raw/RF04331/Sequence_120.ss.ct': pseudoknot detected — pairs (17,33) and (21,40) cross.
# Failed 'Sequence_1200.ss.ct': CT file 'data/raw/RF04331/Sequence_1200.ss.ct': pseudoknot detected — pairs (1,27) and (12,40) cross.
# Failed 'Sequence_1201.ss.ct': CT file 'data/raw/RF04331/Sequence_1201.ss.ct': pseudoknot detected — pairs (9,27) and (10,34) cross.
# Failed 'Sequence_1202.ss.ct': CT file 'data/raw/RF04331/Sequence_1202.ss.ct': pseudoknot detected — pairs (6,20) and (11,30) cross.
# Failed 'Sequence_1204.ss.ct': CT file 'data/raw/RF04331/Sequence_1204.ss.ct': pseudoknot detected — pairs (9,38) and (10,41) cross.
# Failed 'Sequence_1207.ss.ct': CT file 'data/raw/RF04331/Sequence_1207.ss.ct': pseudoknot detected — pairs (1,26) and (5,37) cross.
# Failed 'Sequence_1209.ss.ct': CT file 'data/raw/RF04331/Sequence_1209.ss.ct': pseudoknot detected — pairs (7,14) and (9,20) cross.
# Failed 'Sequence_121.ss.ct': CT file 'data/raw/RF04331/Sequence_121.ss.ct': pseudoknot detected — pairs (5,7) and (6,10) cross.
# Failed 'Sequence_1212.ss.ct': CT file 'data/raw/RF04331/Sequence_1212.ss.ct': pseudoknot detected — pairs (1,42) and (3,45) cross.
# Failed 'Sequence_1213.ss.ct': CT file 'data/raw/RF04331/Sequence_1213.ss.ct': pseudoknot detected — pairs (7,32) and (9,33) cross.
# Failed 'Sequence_1216.ss.ct': CT file 'data/raw/RF04331/Sequence_1216.ss.ct': pseudoknot detected — pairs (9,25) and (14,34) cross.
# Failed 'Sequence_1217.ss.ct': CT file 'data/raw/RF04331/Sequence_1217.ss.ct': pseudoknot detected — pairs (2,10) and (3,37) cross.
# Failed 'Sequence_1219.ss.ct': CT file 'data/raw/RF04331/Sequence_1219.ss.ct': pseudoknot detected — pairs (6,26) and (16,31) cross.
# Failed 'Sequence_122.ss.ct': CT file 'data/raw/RF04331/Sequence_122.ss.ct': pseudoknot detected — pairs (6,37) and (8,43) cross.
# Failed 'Sequence_1220.ss.ct': CT file 'data/raw/RF04331/Sequence_1220.ss.ct': pseudoknot detected — pairs (2,13) and (6,31) cross.
# Failed 'Sequence_1221.ss.ct': CT file 'data/raw/RF04331/Sequence_1221.ss.ct': pseudoknot detected — pairs (6,25) and (7,31) cross.
# Failed 'Sequence_1223.ss.ct': CT file 'data/raw/RF04331/Sequence_1223.ss.ct': pseudoknot detected — pairs (3,41) and (7,43) cross.
# Failed 'Sequence_1225.ss.ct': CT file 'data/raw/RF04331/Sequence_1225.ss.ct': pseudoknot detected — pairs (13,28) and (14,32) cross.
# Failed 'Sequence_1226.ss.ct': CT file 'data/raw/RF04331/Sequence_1226.ss.ct': pseudoknot detected — pairs (3,14) and (8,29) cross.
# Failed 'Sequence_1227.ss.ct': CT file 'data/raw/RF04331/Sequence_1227.ss.ct': pseudoknot detected — pairs (1,14) and (2,21) cross.
# Failed 'Sequence_1228.ss.ct': CT file 'data/raw/RF04331/Sequence_1228.ss.ct': pseudoknot detected — pairs (11,21) and (17,25) cross.
# Failed 'Sequence_1229.ss.ct': CT file 'data/raw/RF04331/Sequence_1229.ss.ct': pseudoknot detected — pairs (2,41) and (24,47) cross.
# Failed 'Sequence_123.ss.ct': CT file 'data/raw/RF04331/Sequence_123.ss.ct': pseudoknot detected — pairs (8,26) and (10,35) cross.
# Failed 'Sequence_1230.ss.ct': CT file 'data/raw/RF04331/Sequence_1230.ss.ct': pseudoknot detected — pairs (16,29) and (17,30) cross.
# Failed 'Sequence_1232.ss.ct': CT file 'data/raw/RF04331/Sequence_1232.ss.ct': pseudoknot detected — pairs (2,10) and (5,18) cross.
# Failed 'Sequence_1233.ss.ct': CT file 'data/raw/RF04331/Sequence_1233.ss.ct': pseudoknot detected — pairs (12,20) and (19,27) cross.
# Failed 'Sequence_1235.ss.ct': CT file 'data/raw/RF04331/Sequence_1235.ss.ct': pseudoknot detected — pairs (1,19) and (12,42) cross.
# Failed 'Sequence_1238.ss.ct': CT file 'data/raw/RF04331/Sequence_1238.ss.ct': pseudoknot detected — pairs (1,19) and (2,20) cross.
# Failed 'Sequence_1239.ss.ct': CT file 'data/raw/RF04331/Sequence_1239.ss.ct': pseudoknot detected — pairs (11,19) and (14,22) cross.
# Failed 'Sequence_124.ss.ct': CT file 'data/raw/RF04331/Sequence_124.ss.ct': pseudoknot detected — pairs (16,27) and (17,28) cross.
# Failed 'Sequence_1240.ss.ct': CT file 'data/raw/RF04331/Sequence_1240.ss.ct': pseudoknot detected — pairs (14,18) and (17,19) cross.
# Failed 'Sequence_1241.ss.ct': CT file 'data/raw/RF04331/Sequence_1241.ss.ct': pseudoknot detected — pairs (13,26) and (17,33) cross.
# Failed 'Sequence_1242.ss.ct': CT file 'data/raw/RF04331/Sequence_1242.ss.ct': pseudoknot detected — pairs (2,16) and (3,18) cross.
# Failed 'Sequence_1243.ss.ct': CT file 'data/raw/RF04331/Sequence_1243.ss.ct': pseudoknot detected — pairs (6,28) and (7,29) cross.
# Failed 'Sequence_1244.ss.ct': CT file 'data/raw/RF04331/Sequence_1244.ss.ct': pseudoknot detected — pairs (1,43) and (10,45) cross.
# Failed 'Sequence_1246.ss.ct': CT file 'data/raw/RF04331/Sequence_1246.ss.ct': pseudoknot detected — pairs (5,20) and (6,22) cross.
# Failed 'Sequence_1248.ss.ct': CT file 'data/raw/RF04331/Sequence_1248.ss.ct': pseudoknot detected — pairs (22,36) and (23,37) cross.
# Failed 'Sequence_1249.ss.ct': CT file 'data/raw/RF04331/Sequence_1249.ss.ct': pseudoknot detected — pairs (8,39) and (9,41) cross.
# Failed 'Sequence_1252.ss.ct': CT file 'data/raw/RF04331/Sequence_1252.ss.ct': pseudoknot detected — pairs (7,33) and (8,35) cross.
# Failed 'Sequence_126.ss.ct': CT file 'data/raw/RF04331/Sequence_126.ss.ct': pseudoknot detected — pairs (18,29) and (23,42) cross.
# Failed 'Sequence_1264.ss.ct': CT file 'data/raw/RF04331/Sequence_1264.ss.ct': pseudoknot detected — pairs (7,33) and (8,34) cross.
# Failed 'Sequence_1266.ss.ct': CT file 'data/raw/RF04331/Sequence_1266.ss.ct': pseudoknot detected — pairs (1,19) and (6,40) cross.
# Failed 'Sequence_1267.ss.ct': CT file 'data/raw/RF04331/Sequence_1267.ss.ct': pseudoknot detected — pairs (3,43) and (31,46) cross.
# Failed 'Sequence_1268.ss.ct': CT file 'data/raw/RF04331/Sequence_1268.ss.ct': pseudoknot detected — pairs (6,30) and (15,33) cross.
# Failed 'Sequence_127.ss.ct': CT file 'data/raw/RF04331/Sequence_127.ss.ct': pseudoknot detected — pairs (1,43) and (3,46) cross.
# Failed 'Sequence_1271.ss.ct': CT file 'data/raw/RF04331/Sequence_1271.ss.ct': pseudoknot detected — pairs (2,16) and (3,28) cross.
# Failed 'Sequence_1273.ss.ct': CT file 'data/raw/RF04331/Sequence_1273.ss.ct': pseudoknot detected — pairs (2,18) and (3,22) cross.
# Failed 'Sequence_1274.ss.ct': CT file 'data/raw/RF04331/Sequence_1274.ss.ct': pseudoknot detected — pairs (6,27) and (7,31) cross.
# Failed 'Sequence_1275.ss.ct': CT file 'data/raw/RF04331/Sequence_1275.ss.ct': pseudoknot detected — pairs (2,23) and (14,24) cross.
# Failed 'Sequence_128.ss.ct': CT file 'data/raw/RF04331/Sequence_128.ss.ct': pseudoknot detected — pairs (9,18) and (12,22) cross.
# Failed 'Sequence_1280.ss.ct': CT file 'data/raw/RF04331/Sequence_1280.ss.ct': pseudoknot detected — pairs (8,41) and (10,45) cross.
# Failed 'Sequence_1281.ss.ct': CT file 'data/raw/RF04331/Sequence_1281.ss.ct': pseudoknot detected — pairs (3,39) and (8,40) cross.
# Failed 'Sequence_1284.ss.ct': CT file 'data/raw/RF04331/Sequence_1284.ss.ct': pseudoknot detected — pairs (9,27) and (11,31) cross.
# Failed 'Sequence_1285.ss.ct': CT file 'data/raw/RF04331/Sequence_1285.ss.ct': pseudoknot detected — pairs (2,34) and (3,38) cross.
# Failed 'Sequence_1287.ss.ct': CT file 'data/raw/RF04331/Sequence_1287.ss.ct': pseudoknot detected — pairs (1,18) and (6,43) cross.
# Failed 'Sequence_1288.ss.ct': CT file 'data/raw/RF04331/Sequence_1288.ss.ct': pseudoknot detected — pairs (7,14) and (11,37) cross.
# Failed 'Sequence_1289.ss.ct': CT file 'data/raw/RF04331/Sequence_1289.ss.ct': pseudoknot detected — pairs (6,27) and (7,50) cross.
# Failed 'Sequence_129.ss.ct': CT file 'data/raw/RF04331/Sequence_129.ss.ct': pseudoknot detected — pairs (7,25) and (11,26) cross.
# Failed 'Sequence_1290.ss.ct': CT file 'data/raw/RF04331/Sequence_1290.ss.ct': pseudoknot detected — pairs (14,32) and (21,38) cross.
# Failed 'Sequence_1292.ss.ct': CT file 'data/raw/RF04331/Sequence_1292.ss.ct': pseudoknot detected — pairs (37,45) and (40,49) cross.
# Failed 'Sequence_1295.ss.ct': CT file 'data/raw/RF04331/Sequence_1295.ss.ct': pseudoknot detected — pairs (3,19) and (12,42) cross.
# Failed 'Sequence_1297.ss.ct': CT file 'data/raw/RF04331/Sequence_1297.ss.ct': pseudoknot detected — pairs (3,21) and (4,40) cross.
# Failed 'Sequence_1298.ss.ct': CT file 'data/raw/RF04331/Sequence_1298.ss.ct': pseudoknot detected — pairs (3,15) and (4,16) cross.
# Failed 'Sequence_13.ss.ct': CT file 'data/raw/RF04331/Sequence_13.ss.ct': pseudoknot detected — pairs (2,25) and (13,43) cross.
# Failed 'Sequence_130.ss.ct': CT file 'data/raw/RF04331/Sequence_130.ss.ct': pseudoknot detected — pairs (2,35) and (5,46) cross.
# Failed 'Sequence_1300.ss.ct': CT file 'data/raw/RF04331/Sequence_1300.ss.ct': pseudoknot detected — pairs (7,36) and (8,37) cross.
# Failed 'Sequence_132.ss.ct': CT file 'data/raw/RF04331/Sequence_132.ss.ct': pseudoknot detected — pairs (5,17) and (7,25) cross.
# Failed 'Sequence_133.ss.ct': CT file 'data/raw/RF04331/Sequence_133.ss.ct': pseudoknot detected — pairs (4,45) and (43,48) cross.
# Failed 'Sequence_135.ss.ct': CT file 'data/raw/RF04331/Sequence_135.ss.ct': pseudoknot detected — pairs (5,13) and (7,14) cross.
# Failed 'Sequence_136.ss.ct': CT file 'data/raw/RF04331/Sequence_136.ss.ct': pseudoknot detected — pairs (1,27) and (8,42) cross.
# Failed 'Sequence_138.ss.ct': CT file 'data/raw/RF04331/Sequence_138.ss.ct': pseudoknot detected — pairs (1,27) and (9,36) cross.
# Failed 'Sequence_141.ss.ct': CT file 'data/raw/RF04331/Sequence_141.ss.ct': pseudoknot detected — pairs (15,37) and (16,43) cross.
# Failed 'Sequence_143.ss.ct': CT file 'data/raw/RF04331/Sequence_143.ss.ct': pseudoknot detected — pairs (13,28) and (18,30) cross.
# Failed 'Sequence_144.ss.ct': CT file 'data/raw/RF04331/Sequence_144.ss.ct': pseudoknot detected — pairs (7,15) and (11,29) cross.
# Failed 'Sequence_149.ss.ct': CT file 'data/raw/RF04331/Sequence_149.ss.ct': pseudoknot detected — pairs (9,28) and (13,46) cross.
# Failed 'Sequence_15.ss.ct': CT file 'data/raw/RF04331/Sequence_15.ss.ct': pseudoknot detected — pairs (3,38) and (7,41) cross.
# Failed 'Sequence_152.ss.ct': CT file 'data/raw/RF04331/Sequence_152.ss.ct': pseudoknot detected — pairs (1,16) and (8,33) cross.
# Failed 'Sequence_153.ss.ct': CT file 'data/raw/RF04331/Sequence_153.ss.ct': pseudoknot detected — pairs (2,15) and (9,44) cross.
# Failed 'Sequence_154.ss.ct': CT file 'data/raw/RF04331/Sequence_154.ss.ct': pseudoknot detected — pairs (1,37) and (10,39) cross.
# Failed 'Sequence_155.ss.ct': CT file 'data/raw/RF04331/Sequence_155.ss.ct': pseudoknot detected — pairs (1,14) and (7,40) cross.
# Failed 'Sequence_156.ss.ct': CT file 'data/raw/RF04331/Sequence_156.ss.ct': pseudoknot detected — pairs (1,17) and (9,29) cross.
# Failed 'Sequence_157.ss.ct': CT file 'data/raw/RF04331/Sequence_157.ss.ct': pseudoknot detected — pairs (5,25) and (8,26) cross.
# Failed 'Sequence_158.ss.ct': CT file 'data/raw/RF04331/Sequence_158.ss.ct': pseudoknot detected — pairs (3,16) and (6,44) cross.
# Failed 'Sequence_163.ss.ct': CT file 'data/raw/RF04331/Sequence_163.ss.ct': pseudoknot detected — pairs (1,20) and (9,42) cross.
# Failed 'Sequence_166.ss.ct': CT file 'data/raw/RF04331/Sequence_166.ss.ct': pseudoknot detected — pairs (4,24) and (5,25) cross.
# Failed 'Sequence_167.ss.ct': CT file 'data/raw/RF04331/Sequence_167.ss.ct': pseudoknot detected — pairs (2,17) and (10,45) cross.
# Failed 'Sequence_168.ss.ct': CT file 'data/raw/RF04331/Sequence_168.ss.ct': pseudoknot detected — pairs (9,18) and (10,19) cross.
# Failed 'Sequence_17.ss.ct': CT file 'data/raw/RF04331/Sequence_17.ss.ct': pseudoknot detected — pairs (2,32) and (5,37) cross.
# Failed 'Sequence_172.ss.ct': CT file 'data/raw/RF04331/Sequence_172.ss.ct': pseudoknot detected — pairs (1,16) and (9,30) cross.
# Failed 'Sequence_173.ss.ct': CT file 'data/raw/RF04331/Sequence_173.ss.ct': pseudoknot detected — pairs (15,21) and (16,22) cross.
# Failed 'Sequence_176.ss.ct': CT file 'data/raw/RF04331/Sequence_176.ss.ct': pseudoknot detected — pairs (1,20) and (10,31) cross.
# Failed 'Sequence_179.ss.ct': CT file 'data/raw/RF04331/Sequence_179.ss.ct': pseudoknot detected — pairs (4,42) and (5,43) cross.
# Failed 'Sequence_18.ss.ct': CT file 'data/raw/RF04331/Sequence_18.ss.ct': pseudoknot detected — pairs (17,26) and (20,28) cross.
# Failed 'Sequence_180.ss.ct': CT file 'data/raw/RF04331/Sequence_180.ss.ct': pseudoknot detected — pairs (1,24) and (14,28) cross.
# Failed 'Sequence_184.ss.ct': CT file 'data/raw/RF04331/Sequence_184.ss.ct': pseudoknot detected — pairs (4,27) and (17,28) cross.
# Failed 'Sequence_187.ss.ct': CT file 'data/raw/RF04331/Sequence_187.ss.ct': pseudoknot detected — pairs (6,26) and (15,27) cross.
# Failed 'Sequence_189.ss.ct': CT file 'data/raw/RF04331/Sequence_189.ss.ct': pseudoknot detected — pairs (28,37) and (29,40) cross.
# Failed 'Sequence_193.ss.ct': CT file 'data/raw/RF04331/Sequence_193.ss.ct': pseudoknot detected — pairs (3,18) and (5,34) cross.
# Failed 'Sequence_194.ss.ct': CT file 'data/raw/RF04331/Sequence_194.ss.ct': pseudoknot detected — pairs (13,28) and (16,29) cross.
# Failed 'Sequence_196.ss.ct': CT file 'data/raw/RF04331/Sequence_196.ss.ct': pseudoknot detected — pairs (2,37) and (3,39) cross.
# Failed 'Sequence_2.ss.ct': CT file 'data/raw/RF04331/Sequence_2.ss.ct': pseudoknot detected — pairs (1,14) and (7,44) cross.
# Failed 'Sequence_20.ss.ct': CT file 'data/raw/RF04331/Sequence_20.ss.ct': pseudoknot detected — pairs (2,24) and (10,46) cross.
# Failed 'Sequence_200.ss.ct': CT file 'data/raw/RF04331/Sequence_200.ss.ct': pseudoknot detected — pairs (13,38) and (14,41) cross.
# Failed 'Sequence_201.ss.ct': CT file 'data/raw/RF04331/Sequence_201.ss.ct': pseudoknot detected — pairs (17,22) and (19,27) cross.
# Failed 'Sequence_206.ss.ct': CT file 'data/raw/RF04331/Sequence_206.ss.ct': pseudoknot detected — pairs (1,16) and (8,42) cross.
# Failed 'Sequence_208.ss.ct': CT file 'data/raw/RF04331/Sequence_208.ss.ct': pseudoknot detected — pairs (9,15) and (11,16) cross.
# Failed 'Sequence_209.ss.ct': CT file 'data/raw/RF04331/Sequence_209.ss.ct': pseudoknot detected — pairs (9,24) and (16,29) cross.
# Failed 'Sequence_21.ss.ct': CT file 'data/raw/RF04331/Sequence_21.ss.ct': pseudoknot detected — pairs (26,30) and (29,42) cross.
# Failed 'Sequence_211.ss.ct': CT file 'data/raw/RF04331/Sequence_211.ss.ct': pseudoknot detected — pairs (11,25) and (20,27) cross.
# Failed 'Sequence_212.ss.ct': CT file 'data/raw/RF04331/Sequence_212.ss.ct': pseudoknot detected — pairs (2,19) and (7,40) cross.
# Failed 'Sequence_213.ss.ct': CT file 'data/raw/RF04331/Sequence_213.ss.ct': pseudoknot detected — pairs (12,22) and (13,24) cross.
# Failed 'Sequence_216.ss.ct': CT file 'data/raw/RF04331/Sequence_216.ss.ct': pseudoknot detected — pairs (5,31) and (6,33) cross.
# Failed 'Sequence_217.ss.ct': CT file 'data/raw/RF04331/Sequence_217.ss.ct': pseudoknot detected — pairs (18,27) and (25,35) cross.
# Failed 'Sequence_22.ss.ct': CT file 'data/raw/RF04331/Sequence_22.ss.ct': pseudoknot detected — pairs (2,21) and (9,41) cross.
# Failed 'Sequence_220.ss.ct': CT file 'data/raw/RF04331/Sequence_220.ss.ct': pseudoknot detected — pairs (5,33) and (6,34) cross.
# Failed 'Sequence_221.ss.ct': CT file 'data/raw/RF04331/Sequence_221.ss.ct': pseudoknot detected — pairs (12,36) and (13,37) cross.
# Failed 'Sequence_223.ss.ct': CT file 'data/raw/RF04331/Sequence_223.ss.ct': pseudoknot detected — pairs (4,29) and (6,30) cross.
# Failed 'Sequence_225.ss.ct': CT file 'data/raw/RF04331/Sequence_225.ss.ct': pseudoknot detected — pairs (11,35) and (12,36) cross.
# Failed 'Sequence_228.ss.ct': CT file 'data/raw/RF04331/Sequence_228.ss.ct': pseudoknot detected — pairs (13,23) and (14,24) cross.
# Failed 'Sequence_23.ss.ct': CT file 'data/raw/RF04331/Sequence_23.ss.ct': pseudoknot detected — pairs (8,31) and (14,32) cross.
# Failed 'Sequence_230.ss.ct': CT file 'data/raw/RF04331/Sequence_230.ss.ct': pseudoknot detected — pairs (2,21) and (8,34) cross.
# Failed 'Sequence_231.ss.ct': CT file 'data/raw/RF04331/Sequence_231.ss.ct': pseudoknot detected — pairs (5,31) and (6,32) cross.
# Failed 'Sequence_233.ss.ct': CT file 'data/raw/RF04331/Sequence_233.ss.ct': pseudoknot detected — pairs (4,34) and (8,36) cross.
# Failed 'Sequence_235.ss.ct': CT file 'data/raw/RF04331/Sequence_235.ss.ct': pseudoknot detected — pairs (3,27) and (8,33) cross.
# Failed 'Sequence_239.ss.ct': CT file 'data/raw/RF04331/Sequence_239.ss.ct': pseudoknot detected — pairs (3,33) and (4,36) cross.
# Failed 'Sequence_240.ss.ct': CT file 'data/raw/RF04331/Sequence_240.ss.ct': pseudoknot detected — pairs (11,24) and (12,27) cross.
# Failed 'Sequence_241.ss.ct': CT file 'data/raw/RF04331/Sequence_241.ss.ct': pseudoknot detected — pairs (5,29) and (12,30) cross.
# Failed 'Sequence_245.ss.ct': CT file 'data/raw/RF04331/Sequence_245.ss.ct': pseudoknot detected — pairs (9,30) and (10,35) cross.
# Failed 'Sequence_247.ss.ct': CT file 'data/raw/RF04331/Sequence_247.ss.ct': pseudoknot detected — pairs (3,36) and (6,37) cross.
# Failed 'Sequence_248.ss.ct': CT file 'data/raw/RF04331/Sequence_248.ss.ct': pseudoknot detected — pairs (2,46) and (3,49) cross.
# Failed 'Sequence_251.ss.ct': CT file 'data/raw/RF04331/Sequence_251.ss.ct': pseudoknot detected — pairs (24,30) and (25,31) cross.
# Failed 'Sequence_253.ss.ct': CT file 'data/raw/RF04331/Sequence_253.ss.ct': pseudoknot detected — pairs (5,14) and (7,35) cross.
# Failed 'Sequence_254.ss.ct': CT file 'data/raw/RF04331/Sequence_254.ss.ct': pseudoknot detected — pairs (1,17) and (8,26) cross.
# Failed 'Sequence_255.ss.ct': CT file 'data/raw/RF04331/Sequence_255.ss.ct': pseudoknot detected — pairs (8,32) and (10,42) cross.
# Failed 'Sequence_256.ss.ct': CT file 'data/raw/RF04331/Sequence_256.ss.ct': pseudoknot detected — pairs (4,22) and (8,44) cross.
# Failed 'Sequence_258.ss.ct': CT file 'data/raw/RF04331/Sequence_258.ss.ct': pseudoknot detected — pairs (4,31) and (6,41) cross.
# Failed 'Sequence_26.ss.ct': CT file 'data/raw/RF04331/Sequence_26.ss.ct': pseudoknot detected — pairs (8,36) and (16,37) cross.
# Failed 'Sequence_261.ss.ct': CT file 'data/raw/RF04331/Sequence_261.ss.ct': pseudoknot detected — pairs (1,20) and (2,22) cross.
# Failed 'Sequence_264.ss.ct': CT file 'data/raw/RF04331/Sequence_264.ss.ct': pseudoknot detected — pairs (2,49) and (3,50) cross.
# Failed 'Sequence_266.ss.ct': CT file 'data/raw/RF04331/Sequence_266.ss.ct': pseudoknot detected — pairs (6,40) and (8,41) cross.
# Failed 'Sequence_267.ss.ct': CT file 'data/raw/RF04331/Sequence_267.ss.ct': pseudoknot detected — pairs (2,10) and (8,39) cross.
# Failed 'Sequence_269.ss.ct': CT file 'data/raw/RF04331/Sequence_269.ss.ct': pseudoknot detected — pairs (5,30) and (7,31) cross.
# Failed 'Sequence_27.ss.ct': CT file 'data/raw/RF04331/Sequence_27.ss.ct': pseudoknot detected — pairs (17,22) and (18,23) cross.
# Failed 'Sequence_272.ss.ct': CT file 'data/raw/RF04331/Sequence_272.ss.ct': pseudoknot detected — pairs (2,20) and (6,27) cross.
# Failed 'Sequence_274.ss.ct': CT file 'data/raw/RF04331/Sequence_274.ss.ct': pseudoknot detected — pairs (1,42) and (4,45) cross.
# Failed 'Sequence_276.ss.ct': CT file 'data/raw/RF04331/Sequence_276.ss.ct': pseudoknot detected — pairs (6,35) and (7,42) cross.
# Failed 'Sequence_277.ss.ct': CT file 'data/raw/RF04331/Sequence_277.ss.ct': pseudoknot detected — pairs (9,27) and (10,29) cross.
# Failed 'Sequence_279.ss.ct': CT file 'data/raw/RF04331/Sequence_279.ss.ct': pseudoknot detected — pairs (3,12) and (4,13) cross.
# Failed 'Sequence_28.ss.ct': CT file 'data/raw/RF04331/Sequence_28.ss.ct': pseudoknot detected — pairs (10,27) and (12,37) cross.
# Failed 'Sequence_282.ss.ct': CT file 'data/raw/RF04331/Sequence_282.ss.ct': pseudoknot detected — pairs (1,26) and (22,32) cross.
# Failed 'Sequence_284.ss.ct': CT file 'data/raw/RF04331/Sequence_284.ss.ct': pseudoknot detected — pairs (1,14) and (6,31) cross.
# Failed 'Sequence_286.ss.ct': CT file 'data/raw/RF04331/Sequence_286.ss.ct': pseudoknot detected — pairs (10,28) and (14,31) cross.
# Failed 'Sequence_29.ss.ct': CT file 'data/raw/RF04331/Sequence_29.ss.ct': pseudoknot detected — pairs (5,37) and (7,38) cross.
# Failed 'Sequence_295.ss.ct': CT file 'data/raw/RF04331/Sequence_295.ss.ct': pseudoknot detected — pairs (3,39) and (4,41) cross.
# Failed 'Sequence_296.ss.ct': CT file 'data/raw/RF04331/Sequence_296.ss.ct': pseudoknot detected — pairs (1,9) and (4,20) cross.
# Failed 'Sequence_297.ss.ct': CT file 'data/raw/RF04331/Sequence_297.ss.ct': pseudoknot detected — pairs (1,45) and (5,46) cross.
# Failed 'Sequence_298.ss.ct': CT file 'data/raw/RF04331/Sequence_298.ss.ct': pseudoknot detected — pairs (1,37) and (5,41) cross.
# Failed 'Sequence_304.ss.ct': CT file 'data/raw/RF04331/Sequence_304.ss.ct': pseudoknot detected — pairs (2,44) and (5,46) cross.
# Failed 'Sequence_305.ss.ct': CT file 'data/raw/RF04331/Sequence_305.ss.ct': pseudoknot detected — pairs (2,16) and (14,20) cross.
# Failed 'Sequence_307.ss.ct': CT file 'data/raw/RF04331/Sequence_307.ss.ct': pseudoknot detected — pairs (7,34) and (8,36) cross.
# Failed 'Sequence_309.ss.ct': CT file 'data/raw/RF04331/Sequence_309.ss.ct': pseudoknot detected — pairs (8,40) and (9,46) cross.
# Failed 'Sequence_31.ss.ct': CT file 'data/raw/RF04331/Sequence_31.ss.ct': pseudoknot detected — pairs (5,43) and (7,44) cross.
# Failed 'Sequence_310.ss.ct': CT file 'data/raw/RF04331/Sequence_310.ss.ct': pseudoknot detected — pairs (11,39) and (12,40) cross.
# Failed 'Sequence_311.ss.ct': CT file 'data/raw/RF04331/Sequence_311.ss.ct': pseudoknot detected — pairs (1,17) and (8,42) cross.
# Failed 'Sequence_312.ss.ct': CT file 'data/raw/RF04331/Sequence_312.ss.ct': pseudoknot detected — pairs (1,47) and (4,48) cross.
# Failed 'Sequence_315.ss.ct': CT file 'data/raw/RF04331/Sequence_315.ss.ct': pseudoknot detected — pairs (5,13) and (6,17) cross.
# Failed 'Sequence_316.ss.ct': CT file 'data/raw/RF04331/Sequence_316.ss.ct': pseudoknot detected — pairs (7,19) and (8,23) cross.
# Failed 'Sequence_317.ss.ct': CT file 'data/raw/RF04331/Sequence_317.ss.ct': pseudoknot detected — pairs (15,26) and (18,30) cross.
# Failed 'Sequence_319.ss.ct': CT file 'data/raw/RF04331/Sequence_319.ss.ct': pseudoknot detected — pairs (2,9) and (6,44) cross.
# Failed 'Sequence_32.ss.ct': CT file 'data/raw/RF04331/Sequence_32.ss.ct': pseudoknot detected — pairs (11,26) and (16,27) cross.
# Failed 'Sequence_320.ss.ct': CT file 'data/raw/RF04331/Sequence_320.ss.ct': pseudoknot detected — pairs (2,15) and (8,44) cross.
# Failed 'Sequence_327.ss.ct': CT file 'data/raw/RF04331/Sequence_327.ss.ct': pseudoknot detected — pairs (5,42) and (6,43) cross.
# Failed 'Sequence_329.ss.ct': CT file 'data/raw/RF04331/Sequence_329.ss.ct': pseudoknot detected — pairs (1,36) and (4,41) cross.
# Failed 'Sequence_33.ss.ct': CT file 'data/raw/RF04331/Sequence_33.ss.ct': pseudoknot detected — pairs (7,37) and (32,40) cross.
# Failed 'Sequence_330.ss.ct': CT file 'data/raw/RF04331/Sequence_330.ss.ct': pseudoknot detected — pairs (9,21) and (13,33) cross.
# Failed 'Sequence_331.ss.ct': CT file 'data/raw/RF04331/Sequence_331.ss.ct': pseudoknot detected — pairs (5,12) and (7,17) cross.
# Failed 'Sequence_333.ss.ct': CT file 'data/raw/RF04331/Sequence_333.ss.ct': pseudoknot detected — pairs (9,15) and (10,17) cross.
# Failed 'Sequence_334.ss.ct': CT file 'data/raw/RF04331/Sequence_334.ss.ct': pseudoknot detected — pairs (2,19) and (3,42) cross.
# Failed 'Sequence_337.ss.ct': CT file 'data/raw/RF04331/Sequence_337.ss.ct': pseudoknot detected — pairs (3,28) and (6,30) cross.
# Failed 'Sequence_339.ss.ct': CT file 'data/raw/RF04331/Sequence_339.ss.ct': pseudoknot detected — pairs (2,43) and (3,46) cross.
# Failed 'Sequence_34.ss.ct': CT file 'data/raw/RF04331/Sequence_34.ss.ct': pseudoknot detected — pairs (11,15) and (12,26) cross.
# Failed 'Sequence_341.ss.ct': CT file 'data/raw/RF04331/Sequence_341.ss.ct': pseudoknot detected — pairs (4,15) and (9,17) cross.
# Failed 'Sequence_346.ss.ct': CT file 'data/raw/RF04331/Sequence_346.ss.ct': pseudoknot detected — pairs (9,32) and (14,33) cross.
# Failed 'Sequence_348.ss.ct': CT file 'data/raw/RF04331/Sequence_348.ss.ct': pseudoknot detected — pairs (4,18) and (13,34) cross.
# Failed 'Sequence_349.ss.ct': CT file 'data/raw/RF04331/Sequence_349.ss.ct': pseudoknot detected — pairs (1,22) and (10,38) cross.
# Failed 'Sequence_35.ss.ct': CT file 'data/raw/RF04331/Sequence_35.ss.ct': pseudoknot detected — pairs (11,36) and (25,37) cross.
# Failed 'Sequence_352.ss.ct': CT file 'data/raw/RF04331/Sequence_352.ss.ct': pseudoknot detected — pairs (5,44) and (10,45) cross.
# Failed 'Sequence_353.ss.ct': CT file 'data/raw/RF04331/Sequence_353.ss.ct': pseudoknot detected — pairs (14,30) and (17,33) cross.
# Failed 'Sequence_354.ss.ct': CT file 'data/raw/RF04331/Sequence_354.ss.ct': pseudoknot detected — pairs (1,37) and (2,41) cross.
# Failed 'Sequence_355.ss.ct': CT file 'data/raw/RF04331/Sequence_355.ss.ct': pseudoknot detected — pairs (17,23) and (22,30) cross.
# Failed 'Sequence_359.ss.ct': CT file 'data/raw/RF04331/Sequence_359.ss.ct': pseudoknot detected — pairs (10,23) and (11,27) cross.
# Failed 'Sequence_360.ss.ct': CT file 'data/raw/RF04331/Sequence_360.ss.ct': pseudoknot detected — pairs (8,13) and (9,39) cross.
# Failed 'Sequence_365.ss.ct': CT file 'data/raw/RF04331/Sequence_365.ss.ct': pseudoknot detected — pairs (1,19) and (3,24) cross.
# Failed 'Sequence_369.ss.ct': CT file 'data/raw/RF04331/Sequence_369.ss.ct': pseudoknot detected — pairs (17,33) and (19,35) cross.
# Failed 'Sequence_37.ss.ct': CT file 'data/raw/RF04331/Sequence_37.ss.ct': pseudoknot detected — pairs (12,20) and (13,36) cross.
# Failed 'Sequence_370.ss.ct': CT file 'data/raw/RF04331/Sequence_370.ss.ct': pseudoknot detected — pairs (7,17) and (8,18) cross.
# Failed 'Sequence_371.ss.ct': CT file 'data/raw/RF04331/Sequence_371.ss.ct': pseudoknot detected — pairs (2,11) and (6,13) cross.
# Failed 'Sequence_375.ss.ct': CT file 'data/raw/RF04331/Sequence_375.ss.ct': pseudoknot detected — pairs (7,30) and (8,33) cross.
# Failed 'Sequence_379.ss.ct': CT file 'data/raw/RF04331/Sequence_379.ss.ct': pseudoknot detected — pairs (12,15) and (13,16) cross.
# Failed 'Sequence_381.ss.ct': CT file 'data/raw/RF04331/Sequence_381.ss.ct': pseudoknot detected — pairs (5,16) and (8,38) cross.
# Failed 'Sequence_382.ss.ct': CT file 'data/raw/RF04331/Sequence_382.ss.ct': pseudoknot detected — pairs (1,19) and (8,38) cross.
# Failed 'Sequence_383.ss.ct': CT file 'data/raw/RF04331/Sequence_383.ss.ct': pseudoknot detected — pairs (2,30) and (17,33) cross.
# Failed 'Sequence_39.ss.ct': CT file 'data/raw/RF04331/Sequence_39.ss.ct': pseudoknot detected — pairs (18,21) and (20,22) cross.
# Failed 'Sequence_393.ss.ct': CT file 'data/raw/RF04331/Sequence_393.ss.ct': pseudoknot detected — pairs (7,31) and (9,34) cross.
# Failed 'Sequence_394.ss.ct': CT file 'data/raw/RF04331/Sequence_394.ss.ct': pseudoknot detected — pairs (4,38) and (5,41) cross.
# Failed 'Sequence_396.ss.ct': CT file 'data/raw/RF04331/Sequence_396.ss.ct': pseudoknot detected — pairs (5,29) and (6,30) cross.
# Failed 'Sequence_398.ss.ct': CT file 'data/raw/RF04331/Sequence_398.ss.ct': pseudoknot detected — pairs (1,21) and (4,31) cross.
# Failed 'Sequence_401.ss.ct': CT file 'data/raw/RF04331/Sequence_401.ss.ct': pseudoknot detected — pairs (1,23) and (11,35) cross.
# Failed 'Sequence_402.ss.ct': CT file 'data/raw/RF04331/Sequence_402.ss.ct': pseudoknot detected — pairs (9,36) and (10,39) cross.
# Failed 'Sequence_404.ss.ct': CT file 'data/raw/RF04331/Sequence_404.ss.ct': pseudoknot detected — pairs (12,39) and (13,42) cross.
# Failed 'Sequence_405.ss.ct': CT file 'data/raw/RF04331/Sequence_405.ss.ct': pseudoknot detected — pairs (2,6) and (3,8) cross.
# Failed 'Sequence_406.ss.ct': CT file 'data/raw/RF04331/Sequence_406.ss.ct': pseudoknot detected — pairs (2,24) and (15,30) cross.
# Failed 'Sequence_407.ss.ct': CT file 'data/raw/RF04331/Sequence_407.ss.ct': pseudoknot detected — pairs (12,21) and (13,24) cross.
# Failed 'Sequence_414.ss.ct': CT file 'data/raw/RF04331/Sequence_414.ss.ct': pseudoknot detected — pairs (1,43) and (3,47) cross.
# Failed 'Sequence_415.ss.ct': CT file 'data/raw/RF04331/Sequence_415.ss.ct': pseudoknot detected — pairs (1,29) and (3,33) cross.
# Failed 'Sequence_416.ss.ct': CT file 'data/raw/RF04331/Sequence_416.ss.ct': pseudoknot detected — pairs (5,30) and (11,31) cross.
# Failed 'Sequence_417.ss.ct': CT file 'data/raw/RF04331/Sequence_417.ss.ct': pseudoknot detected — pairs (22,47) and (23,48) cross.
# Failed 'Sequence_418.ss.ct': CT file 'data/raw/RF04331/Sequence_418.ss.ct': pseudoknot detected — pairs (1,41) and (6,46) cross.
# Failed 'Sequence_419.ss.ct': CT file 'data/raw/RF04331/Sequence_419.ss.ct': pseudoknot detected — pairs (5,17) and (8,27) cross.
# Failed 'Sequence_42.ss.ct': CT file 'data/raw/RF04331/Sequence_42.ss.ct': pseudoknot detected — pairs (7,28) and (11,35) cross.
# Failed 'Sequence_423.ss.ct': CT file 'data/raw/RF04331/Sequence_423.ss.ct': pseudoknot detected — pairs (1,19) and (8,42) cross.
# Failed 'Sequence_425.ss.ct': CT file 'data/raw/RF04331/Sequence_425.ss.ct': pseudoknot detected — pairs (1,37) and (2,45) cross.
# Failed 'Sequence_427.ss.ct': CT file 'data/raw/RF04331/Sequence_427.ss.ct': pseudoknot detected — pairs (6,32) and (7,35) cross.
# Failed 'Sequence_43.ss.ct': CT file 'data/raw/RF04331/Sequence_43.ss.ct': pseudoknot detected — pairs (6,39) and (10,41) cross.
# Failed 'Sequence_433.ss.ct': CT file 'data/raw/RF04331/Sequence_433.ss.ct': pseudoknot detected — pairs (12,14) and (13,16) cross.
# Failed 'Sequence_434.ss.ct': CT file 'data/raw/RF04331/Sequence_434.ss.ct': pseudoknot detected — pairs (17,29) and (18,30) cross.
# Failed 'Sequence_435.ss.ct': CT file 'data/raw/RF04331/Sequence_435.ss.ct': pseudoknot detected — pairs (2,24) and (5,43) cross.
# Failed 'Sequence_437.ss.ct': CT file 'data/raw/RF04331/Sequence_437.ss.ct': pseudoknot detected — pairs (1,46) and (4,48) cross.
# Failed 'Sequence_440.ss.ct': CT file 'data/raw/RF04331/Sequence_440.ss.ct': pseudoknot detected — pairs (3,9) and (5,26) cross.
# Failed 'Sequence_441.ss.ct': CT file 'data/raw/RF04331/Sequence_441.ss.ct': pseudoknot detected — pairs (5,41) and (7,42) cross.
# Failed 'Sequence_442.ss.ct': CT file 'data/raw/RF04331/Sequence_442.ss.ct': pseudoknot detected — pairs (6,22) and (8,43) cross.
# Failed 'Sequence_447.ss.ct': CT file 'data/raw/RF04331/Sequence_447.ss.ct': pseudoknot detected — pairs (2,33) and (4,38) cross.
# Failed 'Sequence_449.ss.ct': CT file 'data/raw/RF04331/Sequence_449.ss.ct': pseudoknot detected — pairs (2,10) and (6,42) cross.
# Failed 'Sequence_452.ss.ct': CT file 'data/raw/RF04331/Sequence_452.ss.ct': pseudoknot detected — pairs (2,20) and (11,28) cross.
# Failed 'Sequence_453.ss.ct': CT file 'data/raw/RF04331/Sequence_453.ss.ct': pseudoknot detected — pairs (4,17) and (6,34) cross.
# Failed 'Sequence_454.ss.ct': CT file 'data/raw/RF04331/Sequence_454.ss.ct': pseudoknot detected — pairs (2,35) and (24,38) cross.
# Failed 'Sequence_455.ss.ct': CT file 'data/raw/RF04331/Sequence_455.ss.ct': pseudoknot detected — pairs (8,24) and (10,28) cross.
# Failed 'Sequence_458.ss.ct': CT file 'data/raw/RF04331/Sequence_458.ss.ct': pseudoknot detected — pairs (1,12) and (5,24) cross.
# Failed 'Sequence_46.ss.ct': CT file 'data/raw/RF04331/Sequence_46.ss.ct': pseudoknot detected — pairs (8,36) and (9,40) cross.
# Failed 'Sequence_460.ss.ct': CT file 'data/raw/RF04331/Sequence_460.ss.ct': pseudoknot detected — pairs (11,30) and (13,31) cross.
# Failed 'Sequence_461.ss.ct': CT file 'data/raw/RF04331/Sequence_461.ss.ct': pseudoknot detected — pairs (2,18) and (12,26) cross.
# Failed 'Sequence_464.ss.ct': CT file 'data/raw/RF04331/Sequence_464.ss.ct': pseudoknot detected — pairs (12,39) and (32,42) cross.
# Failed 'Sequence_465.ss.ct': CT file 'data/raw/RF04331/Sequence_465.ss.ct': pseudoknot detected — pairs (13,21) and (15,27) cross.
# Failed 'Sequence_468.ss.ct': CT file 'data/raw/RF04331/Sequence_468.ss.ct': pseudoknot detected — pairs (4,34) and (8,35) cross.
# Failed 'Sequence_469.ss.ct': CT file 'data/raw/RF04331/Sequence_469.ss.ct': pseudoknot detected — pairs (6,19) and (7,25) cross.
# Failed 'Sequence_472.ss.ct': CT file 'data/raw/RF04331/Sequence_472.ss.ct': pseudoknot detected — pairs (5,11) and (6,16) cross.
# Failed 'Sequence_475.ss.ct': CT file 'data/raw/RF04331/Sequence_475.ss.ct': pseudoknot detected — pairs (2,38) and (3,45) cross.
# Failed 'Sequence_477.ss.ct': CT file 'data/raw/RF04331/Sequence_477.ss.ct': pseudoknot detected — pairs (6,24) and (12,26) cross.
# Failed 'Sequence_48.ss.ct': CT file 'data/raw/RF04331/Sequence_48.ss.ct': pseudoknot detected — pairs (4,39) and (5,45) cross.
# Failed 'Sequence_480.ss.ct': CT file 'data/raw/RF04331/Sequence_480.ss.ct': pseudoknot detected — pairs (12,32) and (20,38) cross.
# Failed 'Sequence_481.ss.ct': CT file 'data/raw/RF04331/Sequence_481.ss.ct': pseudoknot detected — pairs (1,40) and (2,41) cross.
# Failed 'Sequence_482.ss.ct': CT file 'data/raw/RF04331/Sequence_482.ss.ct': pseudoknot detected — pairs (4,39) and (5,42) cross.
# Failed 'Sequence_483.ss.ct': CT file 'data/raw/RF04331/Sequence_483.ss.ct': pseudoknot detected — pairs (7,16) and (9,19) cross.
# Failed 'Sequence_484.ss.ct': CT file 'data/raw/RF04331/Sequence_484.ss.ct': pseudoknot detected — pairs (8,27) and (9,37) cross.
# Failed 'Sequence_485.ss.ct': CT file 'data/raw/RF04331/Sequence_485.ss.ct': pseudoknot detected — pairs (4,41) and (10,42) cross.
# Failed 'Sequence_486.ss.ct': CT file 'data/raw/RF04331/Sequence_486.ss.ct': pseudoknot detected — pairs (8,18) and (15,28) cross.
# Failed 'Sequence_487.ss.ct': CT file 'data/raw/RF04331/Sequence_487.ss.ct': pseudoknot detected — pairs (1,17) and (12,34) cross.
# Failed 'Sequence_491.ss.ct': CT file 'data/raw/RF04331/Sequence_491.ss.ct': pseudoknot detected — pairs (19,25) and (20,27) cross.
# Failed 'Sequence_492.ss.ct': CT file 'data/raw/RF04331/Sequence_492.ss.ct': pseudoknot detected — pairs (16,31) and (21,34) cross.
# ...
# Failed 'Sequence_851.ss.ct': CT file 'data/raw/RF04331/Sequence_851.ss.ct': pseudoknot detected — pairs (13,21) and (14,30) cross.
# Failed 'Sequence_854.ss.ct': CT file 'data/raw/RF04331/Sequence_854.ss.ct': pseudoknot detected — pairs (7,38) and (8,39) cross.
# Failed 'Sequence_855.ss.ct': CT file 'data/raw/RF04331/Sequence_855.ss.ct': pseudoknot detected — pairs (10,16) and (11,17) cross.
# Failed 'Sequence_857.ss.ct': CT file 'data/raw/RF04331/Sequence_857.ss.ct': pseudoknot detected — pairs (7,13) and (9,42) cross.
# Failed 'Sequence_858.ss.ct': CT file 'data/raw/RF04331/Sequence_858.ss.ct': pseudoknot detected — pairs (4,16) and (7,25) cross.
# Failed 'Sequence_859.ss.ct': CT file 'data/raw/RF04331/Sequence_859.ss.ct': pseudoknot detected — pairs (14,24) and (18,25) cross.
# Failed 'Sequence_866.ss.ct': CT file 'data/raw/RF04331/Sequence_866.ss.ct': pseudoknot detected — pairs (8,17) and (9,20) cross.
# Failed 'Sequence_867.ss.ct': CT file 'data/raw/RF04331/Sequence_867.ss.ct': pseudoknot detected — pairs (13,34) and (14,35) cross.
# Failed 'Sequence_868.ss.ct': CT file 'data/raw/RF04331/Sequence_868.ss.ct': pseudoknot detected — pairs (1,41) and (4,43) cross.
# Failed 'Sequence_870.ss.ct': CT file 'data/raw/RF04331/Sequence_870.ss.ct': pseudoknot detected — pairs (12,25) and (13,26) cross.
# Failed 'Sequence_871.ss.ct': CT file 'data/raw/RF04331/Sequence_871.ss.ct': pseudoknot detected — pairs (5,13) and (10,32) cross.
# Failed 'Sequence_872.ss.ct': CT file 'data/raw/RF04331/Sequence_872.ss.ct': pseudoknot detected — pairs (18,39) and (19,44) cross.
# Failed 'Sequence_873.ss.ct': CT file 'data/raw/RF04331/Sequence_873.ss.ct': pseudoknot detected — pairs (3,34) and (32,35) cross.
# Failed 'Sequence_874.ss.ct': CT file 'data/raw/RF04331/Sequence_874.ss.ct': pseudoknot detected — pairs (26,35) and (32,37) cross.
# Failed 'Sequence_875.ss.ct': CT file 'data/raw/RF04331/Sequence_875.ss.ct': pseudoknot detected — pairs (1,37) and (31,46) cross.
# Failed 'Sequence_876.ss.ct': CT file 'data/raw/RF04331/Sequence_876.ss.ct': pseudoknot detected — pairs (1,48) and (2,50) cross.
# Failed 'Sequence_877.ss.ct': CT file 'data/raw/RF04331/Sequence_877.ss.ct': pseudoknot detected — pairs (4,40) and (5,41) cross.
# Failed 'Sequence_878.ss.ct': CT file 'data/raw/RF04331/Sequence_878.ss.ct': pseudoknot detected — pairs (2,37) and (16,43) cross.
# Failed 'Sequence_88.ss.ct': CT file 'data/raw/RF04331/Sequence_88.ss.ct': pseudoknot detected — pairs (2,34) and (3,37) cross.
# Failed 'Sequence_880.ss.ct': CT file 'data/raw/RF04331/Sequence_880.ss.ct': pseudoknot detected — pairs (14,24) and (15,25) cross.
# Failed 'Sequence_882.ss.ct': CT file 'data/raw/RF04331/Sequence_882.ss.ct': pseudoknot detected — pairs (4,14) and (6,19) cross.
# Failed 'Sequence_885.ss.ct': CT file 'data/raw/RF04331/Sequence_885.ss.ct': pseudoknot detected — pairs (1,44) and (2,48) cross.
# Failed 'Sequence_886.ss.ct': CT file 'data/raw/RF04331/Sequence_886.ss.ct': pseudoknot detected — pairs (13,16) and (14,20) cross.
# Failed 'Sequence_889.ss.ct': CT file 'data/raw/RF04331/Sequence_889.ss.ct': pseudoknot detected — pairs (14,37) and (16,40) cross.
# Failed 'Sequence_890.ss.ct': CT file 'data/raw/RF04331/Sequence_890.ss.ct': pseudoknot detected — pairs (3,30) and (12,31) cross.
# Failed 'Sequence_891.ss.ct': CT file 'data/raw/RF04331/Sequence_891.ss.ct': pseudoknot detected — pairs (3,45) and (5,46) cross.
# Failed 'Sequence_892.ss.ct': CT file 'data/raw/RF04331/Sequence_892.ss.ct': pseudoknot detected — pairs (10,27) and (15,30) cross.
# Failed 'Sequence_893.ss.ct': CT file 'data/raw/RF04331/Sequence_893.ss.ct': pseudoknot detected — pairs (9,13) and (12,40) cross.
# Failed 'Sequence_895.ss.ct': CT file 'data/raw/RF04331/Sequence_895.ss.ct': pseudoknot detected — pairs (1,18) and (7,27) cross.
# Failed 'Sequence_897.ss.ct': CT file 'data/raw/RF04331/Sequence_897.ss.ct': pseudoknot detected — pairs (1,10) and (3,35) cross.
# Failed 'Sequence_900.ss.ct': CT file 'data/raw/RF04331/Sequence_900.ss.ct': pseudoknot detected — pairs (1,46) and (3,49) cross.
# Failed 'Sequence_901.ss.ct': CT file 'data/raw/RF04331/Sequence_901.ss.ct': pseudoknot detected — pairs (4,36) and (5,39) cross.
# Failed 'Sequence_902.ss.ct': CT file 'data/raw/RF04331/Sequence_902.ss.ct': pseudoknot detected — pairs (8,36) and (10,41) cross.
# Failed 'Sequence_904.ss.ct': CT file 'data/raw/RF04331/Sequence_904.ss.ct': pseudoknot detected — pairs (2,26) and (11,38) cross.
# Failed 'Sequence_905.ss.ct': CT file 'data/raw/RF04331/Sequence_905.ss.ct': pseudoknot detected — pairs (13,30) and (14,32) cross.
# Failed 'Sequence_906.ss.ct': CT file 'data/raw/RF04331/Sequence_906.ss.ct': pseudoknot detected — pairs (1,19) and (2,20) cross.
# Failed 'Sequence_907.ss.ct': CT file 'data/raw/RF04331/Sequence_907.ss.ct': pseudoknot detected — pairs (10,27) and (11,32) cross.
# Failed 'Sequence_908.ss.ct': CT file 'data/raw/RF04331/Sequence_908.ss.ct': pseudoknot detected — pairs (5,39) and (7,41) cross.
# Failed 'Sequence_910.ss.ct': CT file 'data/raw/RF04331/Sequence_910.ss.ct': pseudoknot detected — pairs (1,46) and (39,48) cross.
# Failed 'Sequence_911.ss.ct': CT file 'data/raw/RF04331/Sequence_911.ss.ct': pseudoknot detected — pairs (17,21) and (19,22) cross.
# Failed 'Sequence_912.ss.ct': CT file 'data/raw/RF04331/Sequence_912.ss.ct': pseudoknot detected — pairs (2,11) and (4,23) cross.
# Failed 'Sequence_913.ss.ct': CT file 'data/raw/RF04331/Sequence_913.ss.ct': pseudoknot detected — pairs (18,42) and (20,45) cross.
# Failed 'Sequence_914.ss.ct': CT file 'data/raw/RF04331/Sequence_914.ss.ct': pseudoknot detected — pairs (1,18) and (2,19) cross.
# Failed 'Sequence_917.ss.ct': CT file 'data/raw/RF04331/Sequence_917.ss.ct': pseudoknot detected — pairs (3,18) and (4,21) cross.
# Failed 'Sequence_918.ss.ct': CT file 'data/raw/RF04331/Sequence_918.ss.ct': pseudoknot detected — pairs (2,15) and (8,43) cross.
# Failed 'Sequence_920.ss.ct': CT file 'data/raw/RF04331/Sequence_920.ss.ct': pseudoknot detected — pairs (1,15) and (8,43) cross.
# Failed 'Sequence_921.ss.ct': CT file 'data/raw/RF04331/Sequence_921.ss.ct': pseudoknot detected — pairs (1,22) and (9,32) cross.
# Failed 'Sequence_922.ss.ct': CT file 'data/raw/RF04331/Sequence_922.ss.ct': pseudoknot detected — pairs (7,30) and (9,33) cross.
# Failed 'Sequence_923.ss.ct': CT file 'data/raw/RF04331/Sequence_923.ss.ct': pseudoknot detected — pairs (16,27) and (17,31) cross.
# Failed 'Sequence_925.ss.ct': CT file 'data/raw/RF04331/Sequence_925.ss.ct': pseudoknot detected — pairs (1,42) and (4,45) cross.
# Failed 'Sequence_928.ss.ct': CT file 'data/raw/RF04331/Sequence_928.ss.ct': pseudoknot detected — pairs (1,37) and (10,43) cross.
# Failed 'Sequence_929.ss.ct': CT file 'data/raw/RF04331/Sequence_929.ss.ct': pseudoknot detected — pairs (3,39) and (4,45) cross.
# Failed 'Sequence_93.ss.ct': CT file 'data/raw/RF04331/Sequence_93.ss.ct': pseudoknot detected — pairs (3,24) and (11,40) cross.
# Failed 'Sequence_930.ss.ct': CT file 'data/raw/RF04331/Sequence_930.ss.ct': pseudoknot detected — pairs (5,30) and (7,32) cross.
# Failed 'Sequence_931.ss.ct': CT file 'data/raw/RF04331/Sequence_931.ss.ct': pseudoknot detected — pairs (1,33) and (6,46) cross.
# Failed 'Sequence_932.ss.ct': CT file 'data/raw/RF04331/Sequence_932.ss.ct': pseudoknot detected — pairs (10,28) and (20,34) cross.
# Failed 'Sequence_933.ss.ct': CT file 'data/raw/RF04331/Sequence_933.ss.ct': pseudoknot detected — pairs (19,33) and (20,41) cross.
# Failed 'Sequence_939.ss.ct': CT file 'data/raw/RF04331/Sequence_939.ss.ct': pseudoknot detected — pairs (22,45) and (25,49) cross.
# Failed 'Sequence_94.ss.ct': CT file 'data/raw/RF04331/Sequence_94.ss.ct': pseudoknot detected — pairs (2,16) and (4,20) cross.
# Failed 'Sequence_942.ss.ct': CT file 'data/raw/RF04331/Sequence_942.ss.ct': pseudoknot detected — pairs (1,16) and (5,46) cross.
# Failed 'Sequence_943.ss.ct': CT file 'data/raw/RF04331/Sequence_943.ss.ct': pseudoknot detected — pairs (6,38) and (7,40) cross.
# Failed 'Sequence_944.ss.ct': CT file 'data/raw/RF04331/Sequence_944.ss.ct': pseudoknot detected — pairs (9,33) and (10,36) cross.
# Failed 'Sequence_948.ss.ct': CT file 'data/raw/RF04331/Sequence_948.ss.ct': pseudoknot detected — pairs (13,35) and (14,36) cross.
# Failed 'Sequence_954.ss.ct': CT file 'data/raw/RF04331/Sequence_954.ss.ct': pseudoknot detected — pairs (2,25) and (11,34) cross.
# Failed 'Sequence_955.ss.ct': CT file 'data/raw/RF04331/Sequence_955.ss.ct': pseudoknot detected — pairs (4,41) and (6,44) cross.
# Failed 'Sequence_956.ss.ct': CT file 'data/raw/RF04331/Sequence_956.ss.ct': pseudoknot detected — pairs (14,41) and (15,43) cross.
# Failed 'Sequence_957.ss.ct': CT file 'data/raw/RF04331/Sequence_957.ss.ct': pseudoknot detected — pairs (2,15) and (10,30) cross.
# Failed 'Sequence_958.ss.ct': CT file 'data/raw/RF04331/Sequence_958.ss.ct': pseudoknot detected — pairs (2,47) and (3,49) cross.
# Failed 'Sequence_959.ss.ct': CT file 'data/raw/RF04331/Sequence_959.ss.ct': pseudoknot detected — pairs (12,21) and (19,22) cross.
# Failed 'Sequence_964.ss.ct': CT file 'data/raw/RF04331/Sequence_964.ss.ct': pseudoknot detected — pairs (3,20) and (12,27) cross.
# Failed 'Sequence_965.ss.ct': CT file 'data/raw/RF04331/Sequence_965.ss.ct': pseudoknot detected — pairs (6,31) and (8,32) cross.
# Failed 'Sequence_966.ss.ct': CT file 'data/raw/RF04331/Sequence_966.ss.ct': pseudoknot detected — pairs (5,41) and (7,42) cross.
# Failed 'Sequence_967.ss.ct': CT file 'data/raw/RF04331/Sequence_967.ss.ct': pseudoknot detected — pairs (5,41) and (7,44) cross.
# Failed 'Sequence_973.ss.ct': CT file 'data/raw/RF04331/Sequence_973.ss.ct': pseudoknot detected — pairs (13,36) and (16,38) cross.
# Failed 'Sequence_976.ss.ct': CT file 'data/raw/RF04331/Sequence_976.ss.ct': pseudoknot detected — pairs (1,40) and (3,42) cross.
# Failed 'Sequence_977.ss.ct': CT file 'data/raw/RF04331/Sequence_977.ss.ct': pseudoknot detected — pairs (1,35) and (3,36) cross.
# Failed 'Sequence_98.ss.ct': CT file 'data/raw/RF04331/Sequence_98.ss.ct': pseudoknot detected — pairs (10,40) and (14,43) cross.
# Failed 'Sequence_981.ss.ct': CT file 'data/raw/RF04331/Sequence_981.ss.ct': pseudoknot detected — pairs (11,13) and (12,28) cross.
# Failed 'Sequence_982.ss.ct': CT file 'data/raw/RF04331/Sequence_982.ss.ct': pseudoknot detected — pairs (13,21) and (14,23) cross.
# Failed 'Sequence_983.ss.ct': CT file 'data/raw/RF04331/Sequence_983.ss.ct': pseudoknot detected — pairs (5,16) and (11,33) cross.
# Failed 'Sequence_986.ss.ct': CT file 'data/raw/RF04331/Sequence_986.ss.ct': pseudoknot detected — pairs (1,20) and (2,25) cross.
# Failed 'Sequence_987.ss.ct': CT file 'data/raw/RF04331/Sequence_987.ss.ct': pseudoknot detected — pairs (2,22) and (14,27) cross.
# Failed 'Sequence_989.ss.ct': CT file 'data/raw/RF04331/Sequence_989.ss.ct': pseudoknot detected — pairs (1,20) and (8,36) cross.
# Failed 'Sequence_990.ss.ct': CT file 'data/raw/RF04331/Sequence_990.ss.ct': pseudoknot detected — pairs (17,25) and (18,26) cross.
# Failed 'Sequence_992.ss.ct': CT file 'data/raw/RF04331/Sequence_992.ss.ct': pseudoknot detected — pairs (1,10) and (6,39) cross.
# Failed 'Sequence_996.ss.ct': CT file 'data/raw/RF04331/Sequence_996.ss.ct': pseudoknot detected — pairs (2,39) and (4,40) cross.
# Failed 'Sequence_998.ss.ct': CT file 'data/raw/RF04331/Sequence_998.ss.ct': pseudoknot detected — pairs (1,37) and (12,41) cross.
# Failed 'Sequence_999.ss.ct': CT file 'data/raw/RF04331/Sequence_999.ss.ct': pseudoknot detected — pairs (12,24) and (14,28) cross.
# CT parsing: 635 parsed, 0 skipped (len), 666 failed → 635 graphs
# Saved processed dataset → data/processed/RF04331/data.pt
# Done!
# Dataset size: 635 samples
# Train: 508 | Val: 127
# Trainable parameters: 152,708
# Epoch   1 | Train 1.4018 | Val 1.3412 | Perp 3.824 | Rec 0.3778 | LR 1.00e-03
#   -> Saved best model (val_loss=1.3412)
# Epoch   2 | Train 1.3616 | Val 1.3353 | Perp 3.801 | Rec 0.3758 | LR 1.00e-03
#   -> Saved best model (val_loss=1.3353)
# Epoch   3 | Train 1.3536 | Val 1.3343 | Perp 3.797 | Rec 0.3742 | LR 1.00e-03
#   -> Saved best model (val_loss=1.3343)
# Epoch   4 | Train 1.3466 | Val 1.3321 | Perp 3.789 | Rec 0.3776 | LR 1.00e-03
#   -> Saved best model (val_loss=1.3321)
# Epoch   5 | Train 1.3444 | Val 1.3290 | Perp 3.777 | Rec 0.3801 | LR 1.00e-03
#   -> Saved best model (val_loss=1.3290)
# Epoch   6 | Train 1.3400 | Val 1.3311 | Perp 3.785 | Rec 0.3783 | LR 1.00e-03
# Epoch   7 | Train 1.3396 | Val 1.3285 | Perp 3.775 | Rec 0.3783 | LR 1.00e-03
#   -> Saved best model (val_loss=1.3285)
# Epoch   8 | Train 1.3406 | Val 1.3285 | Perp 3.776 | Rec 0.3792 | LR 1.00e-03
# Epoch   9 | Train 1.3385 | Val 1.3276 | Perp 3.772 | Rec 0.3789 | LR 1.00e-03
#   -> Saved best model (val_loss=1.3276)
# Epoch  10 | Train 1.3351 | Val 1.3281 | Perp 3.774 | Rec 0.3801 | LR 1.00e-03
# Epoch  11 | Train 1.3373 | Val 1.3294 | Perp 3.779 | Rec 0.3812 | LR 1.00e-03
# Epoch  12 | Train 1.3351 | Val 1.3289 | Perp 3.777 | Rec 0.3794 | LR 1.00e-03
# Epoch  13 | Train 1.3330 | Val 1.3270 | Perp 3.770 | Rec 0.3801 | LR 1.00e-03
#   -> Saved best model (val_loss=1.3270)
# Epoch  14 | Train 1.3341 | Val 1.3304 | Perp 3.782 | Rec 0.3792 | LR 1.00e-03
# Epoch  15 | Train 1.3340 | Val 1.3280 | Perp 3.774 | Rec 0.3814 | LR 1.00e-03
# Epoch  16 | Train 1.3323 | Val 1.3273 | Perp 3.771 | Rec 0.3796 | LR 1.00e-03
# Epoch  17 | Train 1.3323 | Val 1.3283 | Perp 3.775 | Rec 0.3805 | LR 1.00e-03
# Epoch  18 | Train 1.3313 | Val 1.3297 | Perp 3.780 | Rec 0.3764 | LR 1.00e-03
# Epoch  19 | Train 1.3316 | Val 1.3288 | Perp 3.776 | Rec 0.3826 | LR 5.00e-04
# Epoch  20 | Train 1.3298 | Val 1.3257 | Perp 3.765 | Rec 0.3814 | LR 5.00e-04
#   -> Saved best model (val_loss=1.3257)
# Epoch  21 | Train 1.3292 | Val 1.3264 | Perp 3.767 | Rec 0.3848 | LR 5.00e-04
# Epoch  22 | Train 1.3291 | Val 1.3268 | Perp 3.769 | Rec 0.3814 | LR 5.00e-04
# Epoch  23 | Train 1.3286 | Val 1.3258 | Perp 3.765 | Rec 0.3789 | LR 5.00e-04
# Epoch  24 | Train 1.3295 | Val 1.3263 | Perp 3.767 | Rec 0.3828 | LR 5.00e-04
# Epoch  25 | Train 1.3278 | Val 1.3269 | Perp 3.769 | Rec 0.3841 | LR 5.00e-04
# Epoch  26 | Train 1.3308 | Val 1.3261 | Perp 3.766 | Rec 0.3839 | LR 2.50e-04
# Epoch  27 | Train 1.3276 | Val 1.3267 | Perp 3.768 | Rec 0.3841 | LR 2.50e-04
# Epoch  28 | Train 1.3270 | Val 1.3259 | Perp 3.766 | Rec 0.3857 | LR 2.50e-04
# Epoch  29 | Train 1.3275 | Val 1.3257 | Perp 3.765 | Rec 0.3844 | LR 2.50e-04
# Epoch  30 | Train 1.3262 | Val 1.3262 | Perp 3.767 | Rec 0.3830 | LR 2.50e-04
# Epoch  31 | Train 1.3269 | Val 1.3257 | Perp 3.765 | Rec 0.3837 | LR 2.50e-04
# Epoch  32 | Train 1.3278 | Val 1.3261 | Perp 3.766 | Rec 0.3839 | LR 1.25e-04
# Epoch  33 | Train 1.3265 | Val 1.3261 | Perp 3.766 | Rec 0.3828 | LR 1.25e-04
# Epoch  34 | Train 1.3269 | Val 1.3253 | Perp 3.763 | Rec 0.3846 | LR 1.25e-04
#   -> Saved best model (val_loss=1.3253)
# Epoch  35 | Train 1.3266 | Val 1.3260 | Perp 3.766 | Rec 0.3844 | LR 1.25e-04
# Epoch  36 | Train 1.3266 | Val 1.3256 | Perp 3.764 | Rec 0.3839 | LR 1.25e-04
# Epoch  37 | Train 1.3269 | Val 1.3258 | Perp 3.765 | Rec 0.3846 | LR 1.25e-04
# Epoch  38 | Train 1.3257 | Val 1.3255 | Perp 3.764 | Rec 0.3857 | LR 1.25e-04
# Epoch  39 | Train 1.3265 | Val 1.3259 | Perp 3.766 | Rec 0.3839 | LR 1.25e-04
# Epoch  40 | Train 1.3262 | Val 1.3255 | Perp 3.764 | Rec 0.3848 | LR 6.25e-05
# Epoch  41 | Train 1.3252 | Val 1.3256 | Perp 3.764 | Rec 0.3851 | LR 6.25e-05
# Epoch  42 | Train 1.3262 | Val 1.3256 | Perp 3.764 | Rec 0.3846 | LR 6.25e-05
# Epoch  43 | Train 1.3264 | Val 1.3257 | Perp 3.765 | Rec 0.3844 | LR 6.25e-05
# Epoch  44 | Train 1.3251 | Val 1.3256 | Perp 3.764 | Rec 0.3853 | LR 6.25e-05
# Epoch  45 | Train 1.3253 | Val 1.3255 | Perp 3.764 | Rec 0.3848 | LR 6.25e-05
# Epoch  46 | Train 1.3257 | Val 1.3255 | Perp 3.764 | Rec 0.3851 | LR 3.13e-05
# Epoch  47 | Train 1.3253 | Val 1.3254 | Perp 3.764 | Rec 0.3841 | LR 3.13e-05
# Epoch  48 | Train 1.3254 | Val 1.3256 | Perp 3.765 | Rec 0.3846 | LR 3.13e-05
# Epoch  49 | Train 1.3256 | Val 1.3257 | Perp 3.765 | Rec 0.3851 | LR 3.13e-05
# Early stopping at epoch 49 (no improvement for 15 epochs).
# Loss curves saved to loss_curves.png
# Diagnostics saved to diagnostics.png
# Training complete.
